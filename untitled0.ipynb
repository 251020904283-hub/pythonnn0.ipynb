# %% [markdown]
# <a href="https://colab.research.google.com/github/251020904283-hub/pythonnn0.ipynb/blob/main/untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
hall = 11.25
kit = 18.0
liv = 20.0
bed = 10.75
bath = 9.50
areas = [hall, kit, liv, bed, bath]
print(areas)
hall = 11.25
kit = 18.0
liv = 20.0
bed = 10.75
bath = 9.50
areas = [hall, kit, "living room", liv, bed, "bathroom", bath]
print(areas)
hall = 11.25
kit = 18.0
liv = 20.0
bed = 10.75
bath = 9.50
house = [["hallway", hall],
         ["kitchen", kit],
         ["living room", liv]]
print(house)
print(type(house))

areas = ["hallway", 11.25, "kitchen", 18.0, "living room", 20.0, "bedroom", 10.75, "bathroom", 9.50]
print(areas[1])
print(areas[-1])
print(areas[5])
areas = ["hallway", 11.25, "kitchen", 18.0, "living room", 20.0, "bedroom", 10.75, "bathroom", 9.50]
eat_sleep_area = areas[3] + areas[-3]
print(eat_sleep_area)
areas = ["hallway", 11.25, "kitchen", 18.0, "living room", 20.0, "bedroom", 10.75, "bathroom", 9.50]
downstairs = areas[0:6]
upstairs = areas[6:-1]
print(downstairs)
print(upstairs)
areas = ["hallway", 11.25, "kitchen", 18.0, "living room", 20.0, "bedroom", 10.75, "bathroom", 9.50]
downstairs = areas[:6]
upstairs = areas[6:]
print(downstairs)
print(upstairs)
x = [["a", "b", "c"],
     ["d", "e", "f"],
     ["g", "h", "i"]]
x[2][0]
x[2][:2]
areas = ["hallway", 11.25, "kitchen", 18.0, "living room", 20.0, "bedroom", 10.75, "bathroom", 9.50]
areas[-1] = 10.50
areas[4] = 'chill zone'
print(areas)
areas = ["hallway", 11.25, "kitchen", 18.0, "chill zone", 20.0,
         "bedroom", 10.75, "bathroom", 10.50]
areas_1 = areas  + ["poolhouse", 24.5]
areas_2 = list(areas_1)
areas_2.extend(["garage", 15.45])
print(areas_1)
print(areas_2)
areas = ["hallway", 11.25, "kitchen", 18.0,
        "chill zone", 20.0, "bedroom", 10.75,
         "bathroom", 10.50, "poolhouse", 24.5,
         "garage", 15.45]
del(areas[-4])
del(areas[-3])
print(areas)
areas = [11.25, 18.0, 20.0, 10.75, 9.50]
areas_copy = list(areas)
areas_copy[0] = 5.0
print(areas)
var1 = [1, 2, 3, 4]
var2 = True
print(type(var1))
print(len(var1))
out2 = int(var2)
help(complex)
help(sorted)
first = [11.25, 18.0, 20.0]
second = [10.75, 9.50]
full = first + second
full_sorted = sorted(full, reverse=True)
print(full_sorted)
room = "poolhouse"
room_up = room.upper()
print(room, room_up)
print(len(room))
areas = [11.25, 18.0, 20.0, 10.75, 9.50]
print(areas.index(20))
print(areas.count(14.5))
areas = [11.25, 18.0, 20.0, 10.75, 9.50]
areas.append(24.5)
areas.append(15.45)
print(areas)
areas.reverse()
print(areas)
import numpy
arr = numpy.array([1, 2, 3])
print(arr)
import numpy as np
arr = np.array([1, 2, 3])
print(arr)
r = 0.43
import math
C = 2 * math.pi * r
S = math.pi * r **2
print("Chu vi: " + str(C))
print("Diện tích: " + str(S))
r = 192500
from  math import radians
dist = radians(12) * r
print(dist)
# Out:
# [11.25, 18.0, 20.0, 10.75, 9.5]
# [11.25, 18.0, 'living room', 20.0, 10.75, 'bathroom', 9.5]
# [['hallway', 11.25], ['kitchen', 18.0], ['living room', 20.0]]
# <class 'list'>
# 11.25
# 9.5
# 20.0
# 28.75
# ['hallway', 11.25, 'kitchen', 18.0, 'living room', 20.0]
# ['bedroom', 10.75, 'bathroom']
# ['hallway', 11.25, 'kitchen', 18.0, 'living room', 20.0]
# ['bedroom', 10.75, 'bathroom', 9.5]
# ['hallway', 11.25, 'kitchen', 18.0, 'chill zone', 20.0, 'bedroom', 10.75, 'bathroom', 10.5]
# ['hallway', 11.25, 'kitchen', 18.0, 'chill zone', 20.0, 'bedroom', 10.75, 'bathroom', 10.5, 'poolhouse', 24.5]
# ['hallway', 11.25, 'kitchen', 18.0, 'chill zone', 20.0, 'bedroom', 10.75, 'bathroom', 10.5, 'poolhouse', 24.5, 'garage', 15.45]
# ['hallway', 11.25, 'kitchen', 18.0, 'chill zone', 20.0, 'bedroom', 10.75, 'bathroom', 10.5, 'garage', 15.45]
# [11.25, 18.0, 20.0, 10.75, 9.5]
# <class 'list'>
# 4
# Help on class complex in module builtins:
#
# class complex(object)
#  |  complex(real=0, imag=0)
# ...
