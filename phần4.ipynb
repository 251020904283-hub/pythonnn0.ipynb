# %% [markdown]
# <a href="https://colab.research.google.com/github/251020904283-hub/pythonnn0.ipynb/blob/main/ph%E1%BA%A7n4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
areas = ["hallway", 11.25, "kitchen", 18.0, "living room", 20.0, "bedroom", 10.75, "bathroom", 9.50]
print(areas[1])
print(areas[-1])
print(areas[5])
# Out:
# 11.25
# 9.5
# 20.0

# %%
areas = ["hallway", 11.25, "kitchen", 18.0, "living room", 20.0, "bedroom", 10.75, "bathroom", 9.50]
eat_sleep_area = areas[3] + areas[-3]
print(eat_sleep_area)
# Out:
# 28.75

# %%
areas = ["hallway", 11.25, "kitchen", 18.0, "living room", 20.0, "bedroom", 10.75, "bathroom", 9.50]
downstairs = areas[0:6]
upstairs = areas[6:-1]
print(downstairs)
print(upstairs)
# Out:
# ['hallway', 11.25, 'kitchen', 18.0, 'living room', 20.0]
# ['bedroom', 10.75, 'bathroom']

# %%
areas = ["hallway", 11.25, "kitchen", 18.0, "living room", 20.0, "bedroom", 10.75, "bathroom", 9.50]
downstairs = areas[:6]
upstairs = areas[6:]
print(downstairs)
print(upstairs)
# Out:
# ['hallway', 11.25, 'kitchen', 18.0, 'living room', 20.0]
# ['bedroom', 10.75, 'bathroom', 9.5]

# %%
x = [["a", "b", "c"],
     ["d", "e", "f"],
     ["g", "h", "i"]]
x[2][0]
x[2][:2]
# Out:
# ['g', 'h']
