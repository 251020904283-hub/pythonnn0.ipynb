# %% [markdown]
# <a href="https://colab.research.google.com/github/251020904283-hub/pythonnn0.ipynb/blob/main/bt3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input("Enter a positive integer:"))
print(n)

s = 0 # biến số dùng để lưu tổng
# Nhập code của bạn vào đây

print(f"The sum of 1 to {n} is {s}")

n = int(input("Enter a positive integer: "))
print(n)

s = 0   # biến dùng để lưu tổng
i = 0   # bắt đầu từ số chẵn đầu tiên

while i < n:
    s += i
    i += 2   # tăng thêm 2 để luôn là số chẵn

print(f"The sum of even numbers less than {n} is {s}")
# Out:
# Enter a positive integer:34
# 34
# The sum of 1 to 34 is 0
